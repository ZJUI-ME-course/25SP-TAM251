# %%
import sympy as sy
import numpy as np
import math
from math import sin,cos,tan,asin,acos,atan,pi,sqrt

g=9.81
cm=0.01
mm=0.001

def a2p(x):
    return x/180*pi

# %% [markdown]
# 重点知识
# ---
# 1. normal stress 默认朝截面外
# 2. 二力杆
# 3. Shear 的 double single 区别
#
# $$
# \begin{aligned}
# \sigma&=\frac{F}{A_{面积}} 注意一定一定要除面积❗❗❗❗❗\\
# P_{允许}&=\frac{P_{Yield}}{FS_{安全系数}}
# \end{aligned}
# $$

# %%
#吉他→Gpa
#芭蕾舞演员→Kpa
#钢琴的弦→Mpa
#桌角→Pa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = 1 # in
h = 7 # in
sigma = 2 # psi
tau = 8 # psi
alpha = 41 # degrees

alpha=alpha/180*pi

A=h*b/sin(alpha)
Pmax=sigma*A/sin(alpha)
Pmax
# Out:
# 32.52686461265083

# %%
b = 1 # in
h = 3 # in
sigma = 2 # psi
tau = 9 # psi
alpha = 41 # degrees

alpha=a2p(alpha)
S=b*h

f1=sigma/sin(alpha)**2*S
f2=tau/cos(alpha)**2*S

print(f1,f2)
# Out:
# 13.940084833993216 47.40280467866579

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304164000.png](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304164000.png)

# %%
#####本题 要注意stress的方向定义，默认向截面外
A1 = 243 # mm^2
A2 = 132 # mm^2
P1 = 77 # kN
P2 = 107 # kN

sigma1=(-P1+P2)/A1*1000
sigma2=(P2)/A2*1000

print(sigma1,sigma2)
# Out:
# 123.45679012345678 810.6060606060605

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
####factor of safety
A = 263 # mm^2
sigma = 203 # MPa
fs=3

f=sigma*A
fmax=f/fs

fmax/1000
#注意单位!!!
# Out:
# 17.796333333333333

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304163524.png](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304163524.png)

# %%
d = 64 # mm
P = 8 # kN

p=P
S1=pi*(d/2)**2-pi*(d/4)**2
S2=pi*(d/2)**2

s1=-p/S1*1000
s2=-p/S2*1000

print(s1,s2)
# Out:
# -3.315727981081153 -2.486795985810865

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = 3578 # mm^2
P = 25 # kN


A=A*mm*mm
p=P*5/3*1000
sigma=p/A/1000000/-2

sigma
# Out:
# -5.822619713061299

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 281 # mm
b = 270 # mm
c = 190 # mm
d = 255 # mm
e = 210 # mm
P1 = 88 # kN
P2 = 54 # kN
theta = 24 # degrees
dab = 23 # mm

a=a*mm
b=b*mm
c=c*mm
d=d*mm
e=e*mm
p1=P1*1000
p2=P2*1000
theta=a2p(theta)
dab=dab*mm

m1=-p1*b
m2=-p2*(b+c)
l=a*sin(theta)+e+d

f=-(m1+m2)/l/cos(theta)

A=(pi*(dab/2)**2)
sigma=f/A/1000000
sigma

#只要杆子上没有收到 P等直接外力， 就算是二力杆
# Out:
# 221.03562460464062

# %% [markdown]
# ![%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304165842.png](attachment:%E5%BE%AE%E4%BF%A1%E5%9B%BE%E7%89%87_20220304165842.png)

# %%
a = 665 # mm
b = 83 # mm
c = 499 # mm
d = 166 # mm
L = 1663 # mm
w = 6 # kN/m
Ac = 60 # mm^2

a = a*mm
b = b*mm
c = c*mm
d = d*mm
L = L*mm
w = w*1000
Ac = Ac*mm*mm

l=L

f333=0.5*l*w
l333=l/3
m1=-f333*l333

k=a+b
h=d+c
l=sqrt(k*k+h*h)

f_zhongjian=-m1/k
f=f_zhongjian/h*l

f/Ac/1e6/2
# Out:
# 46.37192583488757

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
W = 3 # kN
a = 5 # m
b = 5 # m
d = 12 # mm
theta = 30 # degrees

W=W*1000
d=d*mm

f=W*(a+b)/a-W
d=f/(pi*(d/2)**2)
d/1000000/2  #看清是double 还是 single
# Out:
# 13.26291192432461
