# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.1
# 思路 先算支撑点力，然后逐段=0分析得到V，M
from sympy import *

p=9
a=3


x=S('x')
v1=-p
m1=-p*x
v2=p
m2=p*x-2*p*a
v3=-p
m3=-p*x+4*p*a
print('A,A,A')
print(v1,v1,v2,v2,v3,v3)
print('C,B,C')

print(m1.subs(x,0),m1.subs(x,a),m2.subs(x,a),m2.subs(x,3*a),m3.subs(x,3*a),m3.subs(x,4*a))
# Out:
# A,A,A
# -9 -9 9 9 -9 -9
# C,B,C
# 0 -27 -27 27 27 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.2
# 问题 这里m1并没有把ma记录进去，不是很理解
from sympy import *
from sympy import integrate as i
w=8
a=2
x=S('x')

v1=0
m1=0
v2=10/3*w*a-w*x
m2=-i(w*(x-a),(x,a,x))+7/3*w*a*(x-a)
v3=1/3*w*a
m3=+7/3*w*a*(x-a)-i(w*(x),(x,x-3*a,x-a))


# print(v1,v2,v3)
print('A,C,A')


print(v1)
print(v1)
print(v2.subs(x,a))
print(v2.subs(x,3*a))
print(v3)
print(v3)

# print(m1)
# print(expand(m2).collect(x))
# print(expand(m3).collect(x))
print('A,F,B')

print(m1)
print(m1)
print(m2.subs(x,a))
print(m2.subs(x,3*a))
print(m3.subs(x,3*a))
print(m3.subs(x,4*a))
# Out:
# A,C,A
# 0
# 0
# 37.3333333333333
# 5.33333333333334
# 5.333333333333333
# 5.333333333333333
# A,F,B
# 0
# 0
# 0
# 85.3333333333333
# 85.3333333333333
# 96.0000000000000

# %%
# document.querySelector('input[name="shapeV1"]').value = 'A';
# document.querySelector('input[name="shapeV2"]').value = 'C';
# document.querySelector('input[name="shapeV3"]').value = 'A';
# document.querySelector('input[name="v1_0"]').value = '0';
# document.querySelector('input[name="v1_a"]').value = '0';
# document.querySelector('input[name="v2_a"]').value = '37.333';
# document.querySelector('input[name="v2_c"]').value = '5.33333333333334';
# document.querySelector('input[name="v3_c"]').value = '5.33333333333334';
# document.querySelector('input[name="v3_d"]').value = '5.33333333333334';

# document.querySelector('input[name="shapeM1"]').value = 'A';
# document.querySelector('input[name="shapeM2"]').value = 'F';
# document.querySelector('input[name="shapeM3"]').value = 'B';
# document.querySelector('input[name="m1_0"]').value = '0';
# document.querySelector('input[name="m1_a"]').value = '0';
# document.querySelector('input[name="m2_a"]').value = '0';
# document.querySelector('input[name="m2_c"]').value = '85.3333333333333';
# document.querySelector('input[name="m3_c"]').value = '85.3333333333333';
# document.querySelector('input[name="m3_d"]').value = '96';

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.3
from sympy import *
from sympy import integrate as i
w=5
p=16
a=7
f1=p/2+5/4*w*a
x=S('x')
v1=-w*x
m1=-i(w*x,(x,0,x))
v2=f1-w*a
m2=f1*(x-a)-i(w*x,(x,x-a,x))
v3=f1-w*a-p
m3=f1*(x-a)-i(w*x,(x,x-a,x))-p*(x-2*a)


print(expand(v1).collect(x))
print(expand(m1).collect(x))
print(expand(v2).collect(x))
print(expand(m2).collect(x))
print(expand(v3).collect(x))
print(expand(m3).collect(x))
# Out:
# -5*x
# -5*x**2/2
# 16.7500000000000
# 16.75*x - 239.75
# 0.750000000000000
# 0.75*x - 15.75

# %%
# document.querySelector('input[name="ao_1"]').value = '0';
# document.querySelector('input[name="a1_1"]').value = '-5';
# document.querySelector('input[name="a2_1"]').value = '0';
# document.querySelector('input[name="mao_1"]').value = '0';
# document.querySelector('input[name="ma1_1"]').value = '0';
# document.querySelector('input[name="ma2_1"]').value = '-5/2';

# document.querySelector('input[name="ao_2"]').value = '16.75';
# document.querySelector('input[name="a1_2"]').value = '0';
# document.querySelector('input[name="a2_2"]').value = '0';
# document.querySelector('input[name="mao_2"]').value = '-239.75';
# document.querySelector('input[name="ma1_2"]').value = '16.75';
# document.querySelector('input[name="ma2_2"]').value = '0';

# document.querySelector('input[name="ao_3"]').value = '0.75';
# document.querySelector('input[name="a1_3"]').value = '0';
# document.querySelector('input[name="a2_3"]').value = '0';
# document.querySelector('input[name="mao_3"]').value = '-15.75';
# document.querySelector('input[name="ma1_3"]').value = '0.75';
# document.querySelector('input[name="ma2_3"]').value = '0';

# %%
# 6.4
# 如下

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.5

# %% [markdown]
# ### 注意 中间的向下的箭头是一个拉伸成了长的，可以看到给分点在中间蓝框，所以需要中间的箭头对齐中间

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.7 
# 思路 
# sigma=M*c/I

# 第一步 算中心轴的位置 ybar=sum（yi*si）/sum(si)
# 第二步 I因为中心轴比较抽象，所以我大多数都是用的ad**2+1/12*b*h**2
# 第三步 c取的是距离中心最远的位置.算出来中心轴ybar，之后有可能是到上边界的距离（ytotal-ybar）也可能是ybar

# 从这个题开始我用mm来简化单位换算，因为我注意到大多数题都需要我换算，所以干脆直接换了得了。复制的时候不用自己改

from sympy import *

h = 159 # mm
b = 233 # mm
t1 = 20 # mm
t2 = 24 # mm
Mz = 1311 # N.m
########################################

mm=1e-3;h*=mm;b*=mm;t1*=mm;t2*=mm


y1=t2+0.5*h
y2=0.5*t2

s1=t1*(2*t2+h)
s2=b*t2

ybar=(s1*y1*2+s2*y2+s2*(y2+h+t2))/(2*s1+2*s2)

ro1=s1/(h+t2+t2)
ro2=s2/t2


#直接通过积分算转动惯量
r=S('r')
I11=integrate(ro1*r*r,[r,0,ybar])*2
I12=integrate(ro1*r*r,[r,0,2*t2+h-ybar])*2
I21=integrate(ro2*r*r,[r,ybar-t2,ybar])
I22=integrate(ro2*r*r,[r,t2+h-ybar,2*t2+h-ybar])

I=I11+I12+I21+I22

sigma=Mz*(t2+h+t2-ybar)/I

print(ybar/1e-3)
print(I/1e-3**4/1000000)
print(sigma/1000000)
# Out:
# 103.49999999999999
# 123.737886000000
# 1.09658007249291

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.8
# 先令最下面作为z的0线，s1,s2之间是做差的

from sympy import *

t = 20
Mz = -1599
################################################
from sympy import integrate as i
mm=1e-3;t*=mm


s1=10*t*4*t
s2=-2*t*4*t
y1=5*t
y2=3*t

zbar=(y1*s1+y2*s2)/(s1+s2)
ybar=zbar-3*t
print(ybar/mm)



y=S('y')
w1=4*t
w2=2*t
I1=i(w1*y**2,[y,0,zbar])+i(w1*y**2,[y,0,10*t-zbar])
I2=i(w2*y**2,[y,zbar-5*t,zbar-t])
I=I1-I2
print(I/mm**4/1e6)

sigma1=Mz*zbar/I
# print(sigma1)
sigma2=-Mz*(t*10-zbar)/I
# print(sigma2)
sigma=(max(sigma1,sigma2)) #!!!!!!!!!!!!!!!!!!!!!!!!!!!!注意向上的是-向下的是+
print(sigma/1e6)
# Out:
# 49.999999999999986
# 45.2266666666667
# 3.18197228773585

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 6.9
# 思路
#不要用sqrt,还是要用**（0.5）
#下面作为0线
from sympy import *

R = 28
Mz = -1569
####################################

mm=1e-3;r=R*mm


y1=2*r
s1=3*pi*r**2
y2=4.5*r 
s2=pi*r**2

zbar=(y1*s1+y2*s2)/(s1+s2)
ybar=zbar-2*r 
print(ybar/mm)



y=S('y')
w1=pi*r 
I1=i(w1*y**2,[y,-ybar-2*r,3*r-ybar])

y=S('y')
w2=(r**2-y**2)**(0.5)
#不要用sqrt,还是要用**（0.5）
I2=i(2*w2*y**2,[y,-r,r])+(ybar**2)*(pi*r**2)
I=float(I1-I2)
print(I*1e6)



# 这里注意了，不是直接用距离最远的位置，而是选上下最远，计算sigma，然后取正的，不要负的。

sigma1=Mz*zbar/I
# print(sigma1)
sigma2=-Mz*(r*5-zbar)/I
# print(sigma2)
sigma=abs(max(sigma1,sigma2))  #!!!!!!!!!!!!!!!!!!!!!!!!!!!!注意向上的是-向下的是+

print(sigma.evalf()/1000000)
# Out:
# 17.5000000000000
# 19.028383752961503
# 5.48330858545783

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.10
# 思路
# 下面是0线
# 如果y指向下的话，那么需要写负的y
t = 19
a = 57
######################################

mm=1e-3;t=t*mm;a=a*mm

s1=8*t*12*t
s2=-6*t*2*t

y1=6*t
y2=6*t+a+t

zbar=(s1*y1+s2*y2)/(s1+s2)
ybar=6*t-zbar

print(-ybar/1e-3)
# Out:
# -10.857142857142856

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.111
# 下线为0
# 失误 前面面积平方了，但是后面d**2忘记了 下次虽然可以对着正确的打印，但是更好的方式是手写一遍公式直接对着看

from math import *
from sympy import integrate as i
from sympy import *

t = 17 # mm
a = 17 # mm
r = 51 # mm
ybar = -5.5826 # mm
mm=1e-3;t*=mm;a*=mm;r*=mm;ybar*=mm
########################################

y=S('y')
I1=i(8*t*y**2,[y,-7*t-ybar,7*t-ybar])
I2=(pi/8-8/9/pi)*r**4+pi/2*r**2*(4*r/3/pi+a-ybar)**2
I=I1-I2

print(I.evalf()/1e-3**4/1000000)
# Out:
# 145.062114135577

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 6.12
# 思路同上
# 但是确实是比较麻烦

from sympy import *

a = 1551 # mm
b = 230 # mm
h = 145 # mm
t1 = 20 # mm
t2 = 24 # mm
sigmaT = 11 # MPa
sigmaC = 13 # MPa
###################################


mm=1e-3
import sympy as sy
a*=mm;b*=mm;h*=mm;t1*=mm;t2*=mm;sigmaT*=1e6;sigmaC*=1e6


x,w=sy.S('x,w')


m1=2*t1*h
m2=t2*b
y1=0.5*h
y2=0.5*t2+h
ybar=(m1*y1+m2*y2)/(m1+m2)

I1=integrate(2*t1*x*x,[x,-ybar,h-ybar])
I2=integrate(b*x*x,[x,h-ybar,h+t2-ybar])
I=I1+I2




M1=2*w*a*a
Feq=w*a
Req=2.5*a
M0=Feq*Req-M1

M_up=-M0+a*Feq
M_down=-M0+a*Feq-M1



sigma_左_压=-M_up*(h-ybar)/I   #左上=压
sigma_左_拉=-M_up*(-ybar)/I    #左下=拉
sigma_右_拉=-M_down*(h-ybar)/I #右上=拉
sigma_右_压=-M_down*(-ybar)/I  #右下=压

equ1=sigma_左_压-sigmaC
equ2=sigma_左_拉-sigmaT

equ3=sigma_右_拉-sigmaT
equ4=sigma_右_压-sigmaC  #这一条式子



w1=-sy.solve([equ1],[w])[w]
w2=sy.solve([equ2],[w])[w]
w3=sy.solve([equ3],[w])[w]
w4=-sy.solve([equ4],[w])[w]
w=min(w1,w2,w3,w4)*mm 


print(ybar/1e-3)
print(I/1e6/(1e-3)**4)

print(w)
# Out:
# 113.70494699646642
# 30.6215878563015
# 0.970234792813062
